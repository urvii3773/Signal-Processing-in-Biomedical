# %% [markdown]
# (2)  From your Notebook 02FourierTransform answers:
#
#    This example having the follownig answers.
#
#         1) Noise Threshld on amplitude 4.5 MHZ for the clean first line.
#         2) lines in the acquired signal have a noise level higher than define threshold
#         3) lines are the ones above the noise threshold
#         4) Determine the noise lines
#         5) Spectrum for the noise lines
#
# Relative amplitude of frequencies present in the signal . it can be defined for both discrete time and continuous time signal. Any signal can be represented as mixture of many harmonic frequencies.

# %%
#we have first this command that initialize and matplotlib (library) for plotting and we specify that we want those plots inline in this notebook
# %matplotlib inline

#now we import different packages that will allow to do math, lineal algebra, numerical operations, array operations and plotting
import scipy as Sci
import scipy.linalg
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt

#we use a simple open command for the file (basic Python)
f = open('E:\Jupyter Notebooks\jupyter notebook\ENGI-5631-FA2017-master\UltrasoundSampleSignal.dat','rb')
#we read it using a numpy (therefore the np.) command that allows direct reading from file into an array
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
#we will now populate an array for the time which we now is 1/125MHz step for a total of 15000
x=np.arange(0,15000/125e6,1/125e6)
FirstLine = AllSignal[:15000]
#we first eliminate dc
dataFirstLine = FirstLine - np.mean(FirstLine)
L=len(dataFirstLine)
#the frequencies after fft will be between 0 and 1/2 of the sampling frequency
f=np.arange(0,125e6/2,125e6/15000)
W=np.fft.fft(dataFirstLine)
PyyClean=abs(W)/L
#NoiseThreshold = np.amax(PyyClean)
NoiseThreshold = max(PyyClean)
print("Noise Threshold:"+ str(NoiseThreshold))
#We continue plotting other lines (we will plot every line and there are 460)
totalLines = np.arange(460)
i=0


for index in totalLines:
    
    Remove_DC_Component = AllSignal[index*15000:(index+1)*15000]-np.mean(AllSignal[index*15000:(index+1)*15000])
    Length_Of_All_Lines = len(Remove_DC_Component)
    FFT_Of_Above_Signal = np.fft.fft(Remove_DC_Component)
    Positive_Peaks_Of_Signal = abs(FFT_Of_Above_Signal)/Length_Of_All_Lines
    Amplitude = max(Positive_Peaks_Of_Signal)
     
    if Amplitude > NoiseThreshold:
        i=i+1
        plt.plot(x,AllSignal[index*15000:(index+1)*15000])
        plt.xlabel('Time')
        plt.ylabel('Unsigned Integer Value')
        plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
        print ("the lines which are above the threshold: " )
        print(str(index))
print "Total no of lines above the threshold are " + str(i)
# Out:
# Noise Threshold:120.198226193
# the lines which are above the threshold:
# 74
# the lines which are above the threshold:
# 75
# the lines which are above the threshold:
# 83
# the lines which are above the threshold:
# 84
# the lines which are above the threshold:
# 85
# the lines which are above the threshold:
# 86
# the lines which are above the threshold:
# 87
# the lines which are above the threshold:
# 88
# the lines which are above the threshold:
# 89
# the lines which are above the threshold:
# 90
# the lines which are above the threshold:
# 91
# the lines which are above the threshold:
# 92
# the lines which are above the threshold:
# 93
# the lines which are above the threshold:
# 94
# the lines which are above the threshold:
# 95
# the lines which are above the threshold:
# 96
# the lines which are above the threshold:
# 97
# the lines which are above the threshold:
# 98
# the lines which are above the threshold:
# 99
# the lines which are above the threshold:
# 100
# the lines which are above the threshold:
# 101
# the lines which are above the threshold:
# 102
# the lines which are above the threshold:
# 103
# the lines which are above the threshold:
# 104
# the lines which are above the threshold:
# 105
# the lines which are above the threshold:
# 106
# the lines which are above the threshold:
# 107
# the lines which are above the threshold:
# 108
# the lines which are above the threshold:
# 109
# the lines which are above the threshold:
# 110
# the lines which are above the threshold:
# 111
# the lines which are above the threshold:
# 112
# the lines which are above the threshold:
# 113
# the lines which are above the threshold:
# 114
# the lines which are above the threshold:
# 115
# the lines which are above the threshold:
# 116
# the lines which are above the threshold:
# 117
# the lines which are above the threshold:
# 149
# the lines which are above the threshold:
# 150
# the lines which are above the threshold:
# 151
# the lines which are above the threshold:
# 152
# the lines which are above the threshold:
# 153
# the lines which are above the threshold:
# 154
# the lines which are above the threshold:
# 155
# the lines which are above the threshold:
# 156
# the lines which are above the threshold:
# 157
# the lines which are above the threshold:
# 158
# the lines which are above the threshold:
# 159
# the lines which are above the threshold:
# 160
# the lines which are above the threshold:
# 161
# the lines which are above the threshold:
# 162
# the lines which are above the threshold:
# 163
# the lines which are above the threshold:
# 164
# the lines which are above the threshold:
# 165
# the lines which are above the threshold:
# 166
# the lines which are above the threshold:
# 167
# the lines which are above the threshold:
# 168
# the lines which are above the threshold:
# 169
# the lines which are above the threshold:
# 170
# the lines which are above the threshold:
# 171
# the lines which are above the threshold:
# 172
# the lines which are above the threshold:
# 173
# the lines which are above the threshold:
# 174
# the lines which are above the threshold:
# 175
# the lines which are above the threshold:
# 176
# the lines which are above the threshold:
# 177
# the lines which are above the threshold:
# 178
# the lines which are above the threshold:
# 179
# the lines which are above the threshold:
# 180
# the lines which are above the threshold:
# 181
# the lines which are above the threshold:
# 182
# the lines which are above the threshold:
# 183
# the lines which are above the threshold:
# 184
# the lines which are above the threshold:
# 185
# the lines which are above the threshold:
# 186
# the lines which are above the threshold:
# 187
# the lines which are above the threshold:
# 214
# the lines which are above the threshold:
# 215
# the lines which are above the threshold:
# 216
# the lines which are above the threshold:
# 217
# the lines which are above the threshold:
# 218
# the lines which are above the threshold:
# 219
# the lines which are above the threshold:
# 220
# the lines which are above the threshold:
# 221
# the lines which are above the threshold:
# 222
# the lines which are above the threshold:
# 223
# the lines which are above the threshold:
# 224
# the lines which are above the threshold:
# 225
# the lines which are above the threshold:
# 226
# the lines which are above the threshold:
# 227
# the lines which are above the threshold:
# 228
# the lines which are above the threshold:
# 229
# the lines which are above the threshold:
# 230
# the lines which are above the threshold:
# 231
# the lines which are above the threshold:
# 232
# the lines which are above the threshold:
# 233
# the lines which are above the threshold:
# 234
# the lines which are above the threshold:
# 235
# the lines which are above the threshold:
# 236
# the lines which are above the threshold:
# 237
# the lines which are above the threshold:
# 238
# the lines which are above the threshold:
# 239
# the lines which are above the threshold:
# 240
# the lines which are above the threshold:
# 241
# the lines which are above the threshold:
# 242
# the lines which are above the threshold:
# 243
# the lines which are above the threshold:
# 244
# the lines which are above the threshold:
# 245
# the lines which are above the threshold:
# 246
# the lines which are above the threshold:
# 247
# the lines which are above the threshold:
# 248
# the lines which are above the threshold:
# 249
# the lines which are above the threshold:
# 250
# the lines which are above the threshold:
# 251
# the lines which are above the threshold:
# 252
# the lines which are above the threshold:
# 264
# the lines which are above the threshold:
# 268
# the lines which are above the threshold:
# 269
# the lines which are above the threshold:
# 270
# the lines which are above the threshold:
# 271
# the lines which are above the threshold:
# 272
# the lines which are above the threshold:
# 273
# the lines which are above the threshold:
# 274
# the lines which are above the threshold:
# 275
# the lines which are above the threshold:
# 276
# the lines which are above the threshold:
# 277
# the lines which are above the threshold:
# 278
# the lines which are above the threshold:
# 279
# the lines which are above the threshold:
# 280
# the lines which are above the threshold:
# 281
# the lines which are above the threshold:
# 282
# the lines which are above the threshold:
# 283
# the lines which are above the threshold:
# 284
# the lines which are above the threshold:
# 285
# the lines which are above the threshold:
# 286
# the lines which are above the threshold:
# 287
# the lines which are above the threshold:
# 288
# the lines which are above the threshold:
# 289
# the lines which are above the threshold:
# 290
# the lines which are above the threshold:
# 291
# the lines which are above the threshold:
# 292
# the lines which are above the threshold:
# 293
# the lines which are above the threshold:
# 294
# the lines which are above the threshold:
# 295
# the lines which are above the threshold:
# 296
# the lines which are above the threshold:
# 297
# the lines which are above the threshold:
# 298
# the lines which are above the threshold:
# 299
# the lines which are above the threshold:
# 300
# the lines which are above the threshold:
# 301
# the lines which are above the threshold:
# 302
# the lines which are above the threshold:
# 303
# the lines which are above the threshold:
# 304
# the lines which are above the threshold:
# 305
# the lines which are above the threshold:
# 306
# the lines which are above the threshold:
# 307
# the lines which are above the threshold:
# 308
# the lines which are above the threshold:
# 309
# the lines which are above the threshold:
# 310
# the lines which are above the threshold:
# 311
# the lines which are above the threshold:
# 312
# the lines which are above the threshold:
# 313
# the lines which are above the threshold:
# 314
# the lines which are above the threshold:
# 315
# the lines which are above the threshold:
# 316
# the lines which are above the threshold:
# 317
# the lines which are above the threshold:
# 318
# the lines which are above the threshold:
# 319
# the lines which are above the threshold:
# 320
# the lines which are above the threshold:
# 321
# the lines which are above the threshold:
# 322
# the lines which are above the threshold:
# 323
# the lines which are above the threshold:
# 324
# the lines which are above the threshold:
# 325
# the lines which are above the threshold:
# 326
# the lines which are above the threshold:
# 327
# the lines which are above the threshold:
# 328
# the lines which are above the threshold:
# 329
# the lines which are above the threshold:
# 330
# the lines which are above the threshold:
# 331
# the lines which are above the threshold:
# 332
# the lines which are above the threshold:
# 333
# the lines which are above the threshold:
# 334
# the lines which are above the threshold:
# 335
# the lines which are above the threshold:
# 336
# the lines which are above the threshold:
# 337
# the lines which are above the threshold:
# 338
# the lines which are above the threshold:
# 339
# the lines which are above the threshold:
# 340
# the lines which are above the threshold:
# 341
# the lines which are above the threshold:
# 342
# the lines which are above the threshold:
# 343
# the lines which are above the threshold:
# 344
# the lines which are above the threshold:
# 345
# the lines which are above the threshold:
# 346
# the lines which are above the threshold:
# 347
# the lines which are above the threshold:
# 348
# the lines which are above the threshold:
# 349
# the lines which are above the threshold:
# 350
# the lines which are above the threshold:
# 351
# the lines which are above the threshold:
# 352
# the lines which are above the threshold:
# 353
# the lines which are above the threshold:
# 354
# the lines which are above the threshold:
# 355
# the lines which are above the threshold:
# 356
# the lines which are above the threshold:
# 357
# the lines which are above the threshold:
# 358
# the lines which are above the threshold:
# 359
# the lines which are above the threshold:
# 360
# the lines which are above the threshold:
# 361
# the lines which are above the threshold:
# 362
# the lines which are above the threshold:
# 363
# the lines which are above the threshold:
# 364
# the lines which are above the threshold:
# 365
# the lines which are above the threshold:
# 366
# the lines which are above the threshold:
# 367
# the lines which are above the threshold:
# 368
# the lines which are above the threshold:
# 369
# the lines which are above the threshold:
# 370
# the lines which are above the threshold:
# 371
# the lines which are above the threshold:
# 372
# the lines which are above the threshold:
# 373
# the lines which are above the threshold:
# 374
# the lines which are above the threshold:
# 375
# the lines which are above the threshold:
# 376
# the lines which are above the threshold:
# 377
# the lines which are above the threshold:
# 378
# the lines which are above the threshold:
# 379
# the lines which are above the threshold:
# 380
# the lines which are above the threshold:
# 381
# the lines which are above the threshold:
# 382
# the lines which are above the threshold:
# 383
# the lines which are above the threshold:
# 384
# the lines which are above the threshold:
# 385
# the lines which are above the threshold:
# 386
# the lines which are above the threshold:
# 387
# the lines which are above the threshold:
# 388
# the lines which are above the threshold:
# 389
# the lines which are above the threshold:
# 390
# the lines which are above the threshold:
# 391
# the lines which are above the threshold:
# 392
# the lines which are above the threshold:
# 393
# the lines which are above the threshold:
# 394
# the lines which are above the threshold:
# 395
# the lines which are above the threshold:
# 396
# the lines which are above the threshold:
# 397
# the lines which are above the threshold:
# 398
# the lines which are above the threshold:
# 399
# the lines which are above the threshold:
# 400
# the lines which are above the threshold:
# 401
# the lines which are above the threshold:
# 402
# the lines which are above the threshold:
# 403
# the lines which are above the threshold:
# 404
# the lines which are above the threshold:
# 405
# the lines which are above the threshold:
# 406
# the lines which are above the threshold:
# 407
# the lines which are above the threshold:
# 408
# the lines which are above the threshold:
# 409
# the lines which are above the threshold:
# 410
# the lines which are above the threshold:
# 411
# the lines which are above the threshold:
# 412
# the lines which are above the threshold:
# 413
# the lines which are above the threshold:
# 414
# the lines which are above the threshold:
# 415
# the lines which are above the threshold:
# 416
# the lines which are above the threshold:
# 417
# the lines which are above the threshold:
# 418
# the lines which are above the threshold:
# 419
# the lines which are above the threshold:
# 420
# the lines which are above the threshold:
# 421
# the lines which are above the threshold:
# 422
# the lines which are above the threshold:
# 423
# the lines which are above the threshold:
# 424
# the lines which are above the threshold:
# 425
# the lines which are above the threshold:
# 426
# the lines which are above the threshold:
# 427
# the lines which are above the threshold:
# 428
# the lines which are above the threshold:
# 429
# the lines which are above the threshold:
# 430
# the lines which are above the threshold:
# 431
# the lines which are above the threshold:
# 432
# the lines which are above the threshold:
# 433
# the lines which are above the threshold:
# 434
# the lines which are above the threshold:
# 435
# the lines which are above the threshold:
# 436
# the lines which are above the threshold:
# 437
# the lines which are above the threshold:
# 438
# the lines which are above the threshold:
# 439
# the lines which are above the threshold:
# 440
# the lines which are above the threshold:
# 441
# the lines which are above the threshold:
# 442
# the lines which are above the threshold:
# 443
# the lines which are above the threshold:
# 444
# the lines which are above the threshold:
# 445
# the lines which are above the threshold:
# 446
# the lines which are above the threshold:
# 447
# the lines which are above the threshold:
# 448
# the lines which are above the threshold:
# 449
# the lines which are above the threshold:
# 450
# the lines which are above the threshold:
# 451
# the lines which are above the threshold:
# 452
# the lines which are above the threshold:
# 453
# the lines which are above the threshold:
# 454
# the lines which are above the threshold:
# 455
# the lines which are above the threshold:
# 456
# the lines which are above the threshold:
# 457
# the lines which are above the threshold:
# 458
# the lines which are above the threshold:
# 459
# Total no of lines above the threshold are 308
